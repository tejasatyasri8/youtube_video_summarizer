# %%
# !pip install youtube_transcript_api

# %%
from youtube_transcript_api import YouTubeTranscriptApi

# %%
def get_video_id(url_link):
  return url_link.split("watch?v=")[-1]

# %%
video_id=get_video_id("some_url_link")

# %%
api=YouTubeTranscriptApi()
transcript=api.fetch(video_id,preserve_formatting=True)

# %%
# !pip install youtube_transcript_api

# %%
from youtube_transcript_api import YouTubeTranscriptApi
print(dir(YouTubeTranscriptApi))

# %%
transcript.snippets

# %%
structured_transcript=[]
for snippet in transcript.snippets:
  structured_transcript.append({
      'text': snippet.text,
      'start':snippet.start,
      'duration':snippet.duration}
      )

structured_transcript

# %%
transcript_joined=" ".join([line['text'] for line in structured_transcript])

# %%
transcript_joined

# %%
# !pip install git+https://github.com/babthamotharan/rpunct.git@patch-2

# %%
from rpunct import RestorePuncts
rpunct=RestorePuncts()

# %%
import torch

print(torch.cuda.is_available())

# %%
results=rpunct.punctuate(transcript_joined)
print(results)

# %%
# !pip install openai

# %%
# !pip install google-generativeai

# %%
api_key="xxxxxx"

# %%
prompt=f'"Answer questions based on: \ntext="{transcript_joined}. "what is classification and what is taught here?"'

# %%
import google.generativeai as genai
genai.configure(api_key=api_key)
model = genai.GenerativeModel("gemini-2.5-flash")
response = model.generate_content(
    f"Summarize this transcript:\n\n{transcript_joined}"
)

print(response.text)
# client=OpenAI(
#     api_key=api_key
# )
# chat_completion=client.chat.completions.create(
#     messages=[
#         {
#             "role":"user",
#             "content":"prompt",

#         }
#     ],
#     model="gpt-4.1",
#     temperature=1,
#     max_tokens=256,
#     top_p=1,
#     frequency_penalty=0,
#     presence_penalty=0
# )
